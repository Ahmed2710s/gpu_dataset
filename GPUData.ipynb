# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed2710s/gpu_dataset/blob/main/GPUData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mydata = pd.read_csv('GPUData.csv')

mydata.head(5)
# Out:
#                                        Name Price  Producer  \
# 0      Sapphire Pulse Radeon RX 6600 Gaming   NaN  SAPPHIRE
# 1                     Aorus RTX 3070 Master   NaN  Gigabyte
# 2           ASRock Arc A750 Challenger D OC   NaN    ASRock
# 3      ASRock Radeon RX 7600 Challenger 8GO   NaN    ASRock
# 4  ASRock Radeon RX 7600 Phantom Gaming 8GO   NaN    ASRock
#
#                    MPN            EAN  UPC    Length  Slots  8-Pin Connectors  \
# 0         11310-01-20G  4895106290662  NaN    193 mm    2.5                 1
# 1  GV-N3070AORUS M-8GD  4719331307844  NaN    290 mm    3.0                 2
# 2     90-GA3HZZ-00UANF  4710483940316  NaN    271 mm    2.0                 2
# 3     90-GA41ZZ-00UANF  4710483942037  NaN  269.2 mm    2.0                 1
# 4     90-GA4BZZ-00UANF  4710483943133  NaN    305 mm    2.5                 1
#
#    6-Pin Connectors  HDMI  DisplayPort  DVI VGA Boost Clock  Vram  \
# ...

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1417 entries, 0 to 1416
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              1417 non-null   object
#  1   Price             376 non-null    object
#  2   Producer          1417 non-null   object
#  3   MPN               1417 non-null   object
#  4   EAN               1417 non-null   int64
#  5   UPC               343 non-null    float64
#  6   Length            1417 non-null   object
#  7   Slots             1403 non-null   float64
#  8   8-Pin Connectors  1417 non-null   int64
#  9   6-Pin Connectors  1417 non-null   int64
#  10  HDMI              1417 non-null   int64
#  11  DisplayPort       1417 non-null   int64
#  12  DVI               1417 non-null   int64
#  13  VGA               1417 non-null   object
#  14  Boost Clock       1417 non-null   object
#  15  Vram              1417 non-null   object
# ...

# %%
mydata.describe()
# Out:
#                 EAN           UPC        Slots  8-Pin Connectors  \
# count  1.417000e+03  3.430000e+02  1403.000000       1417.000000
# mean   4.127106e+12  8.592901e+11     2.334063          1.110797
# std    1.399263e+12  5.098719e+11     0.534336          0.803244
# min    1.230320e+10  1.928760e+11     1.000000          0.000000
# 25%    4.250812e+12  8.241422e+11     2.000000          1.000000
# 50%    4.718018e+12  8.433681e+11     2.000000          1.000000
# 75%    4.719331e+12  8.895230e+11     2.550000          2.000000
# max    8.717249e+12  4.895147e+12     5.000000          3.000000
#
#        6-Pin Connectors         HDMI  DisplayPort          DVI
# count       1417.000000  1417.000000  1417.000000  1417.000000
# mean           0.275229     0.969654     1.840508     0.206775
# std            0.475873     0.671081     1.252668     0.432127
# min            0.000000     0.000000     0.000000     0.000000
# 25%            0.000000     1.000000     1.000000     0.000000
# ...

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

mydata.hist(figsize=(30,40))
plt.show()

# %%
pd.crosstab(mydata['Producer'],mydata['Price'])
# Out:
# Price       $1034.26 USD  $105.9 USD  $109.82 USD  $111.13 USD  $112.43 USD  \
# Producer
# ASRock                 0           0            0            0            0
# ASUS                   0           0            0            0            1
# EVGA                   0           0            1            0            0
# Gigabyte               1           0            0            0            0
# MSI                    0           0            0            0            0
# PNY                    0           0            0            0            0
# PowerColor             0           0            0            0            0
# SAPPHIRE               0           0            0            0            0
# Sapphire               0           1            0            0            0
# XFX                    0           0            0            0            0
# ZOTAC                  0           0            0            1            0
#
# ...

# %%
pd.crosstab(mydata['Name'],mydata['HDMI'] )
# Out:
# HDMI                                        0  1  2  3
# Name
# ASRock Arc A380 Challenger ITX              0  1  0  0
# ASRock Arc A750 Challenger D OC             0  0  1  0
# ASRock Radeon RX 6950 XT Phantom Gaming OC  0  1  0  0
# ASRock Radeon RX 7600 Challenger 8GO        0  1  0  0
# ASRock Radeon RX 7600 Phantom Gaming 8GO    0  1  0  0
# ...                                        .. .. .. ..
# ZOTAC GeForce GTX 1080 Ti Mini              1  0  0  0
# ZOTAC GeForce RTX 3080 Ti Trinity           0  1  0  0
# ZOTAC GeForce RTX 3080 Ti Trinity OC        0  1  0  0
# Zotac Gaming RTX 3070 Twin Edge             0  1  0  0
# Zotac Gaming RTX 3070 Twin Edge OC          0  1  0  0
#
# [1385 rows x 4 columns]

# %%
mydata['HDMI'].std()
# Out:
# 0.6710809701316436

# %%
mydata['HDMI'].mean()
# Out:
# np.float64(0.9696541990119972)

# %%
sns.displot(mydata['HDMI'])

# %%
mydata.hist(by='HDMI',column = 'Producer')
# Out:
# array([[<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>],
#        [<Axes: title={'center': '2'}>, <Axes: title={'center': '3'}>]],
#       dtype=object)

# %%
mydata.hist(by='Producer',column = 'Vram', figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'ASRock'}>,
#         <Axes: title={'center': 'ASUS'}>,
#         <Axes: title={'center': 'Club 3D'}>,
#         <Axes: title={'center': 'EVGA'}>],
#        [<Axes: title={'center': 'Gainward'}>,
#         <Axes: title={'center': 'Galax'}>,
#         <Axes: title={'center': 'Gigabyte'}>,
#         <Axes: title={'center': 'HIS'}>],
#        [<Axes: title={'center': 'INNO3D'}>,
#         <Axes: title={'center': 'Intel'}>,
#         <Axes: title={'center': 'KFA2'}>,
#         <Axes: title={'center': 'MSI'}>],
#        [<Axes: title={'center': 'PNY'}>,
#         <Axes: title={'center': 'Palit'}>,
#         <Axes: title={'center': 'PowerColor'}>,
#         <Axes: title={'center': 'SAPPHIRE'}>],
#        [<Axes: title={'center': 'Sapphire'}>,
#         <Axes: title={'center': 'Sparkle'}>,
#         <Axes: title={'center': 'XFX'}>,
#         <Axes: title={'center': 'ZOTAC'}>]], dtype=object)

# %%
x = st.skewnorm.rvs(10, size=1000)
x[0:20]
# Out:
# array([-0.01487535,  0.62207469,  0.89755428,  1.23099127,  0.78986   ,
#         1.17207542,  0.72441747,  0.34719953,  0.89587309, -0.04786627,
#         1.23598854,  0.40146991, -0.04451358,  1.36277007,  0.03354076,
#         0.20231803,  0.69002613,  0.16530291,  1.40109119,  0.21023485])

# %%
fig, ax = plt.subplots()
_ = plt.hist(x, color = 'lightgray')

# %%
data = np.random.randn(7500)


m = data.mean()
s = data.std()


plt.hist(data)

plt.axvline(m,color='red', label="Mean")

plt.axvline(m + 2*s, linestyle="--", label="+2 Std")
plt.axvline(m - 2*s, linestyle="--", label="-2 Std")

plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
plt.axvline(x = np.mean(x), color='orange')
plt.axvline(x = np.median(x), color='green')
_ = plt.hist(x, color = 'lightgray')

# %%
_ = np.random.normal(size=10000)


sns.set_style('ticks')


sns.displot(x, kde=True)

# Mean and standard deviation
print("Mean:", x.mean())
print("Std:", x.std())
# Out:
# Mean: 0.7769829176680602
# Std: 0.6255931598548333

# %%
x = np.random.normal(size=10000)
sns.set_style('ticks')
_ = sns.displot(x, kde=True)

# %%
x_sample = np.random.choice(x, size=10, replace=False)

print("Sample:", x_sample)

print("Sample Mean:", x_sample.mean())
# Out:
# Sample: [ 0.33553046 -0.4644892  -0.16479306 -2.06350013 -0.56013979 -0.1772171
#   0.49535513 -1.38892774  1.80534089  0.63812149]
# Sample Mean: -0.15447190548541737

# %%
m = np.concatenate((np.random.normal(size=5000), np.random.normal(loc = 4.0, size=5000)))

# %%
_ = sns.displot(m, kde=True)

# %%
x_i = 85
mu = 60
sigma = 10

# %%
x = np.random.normal(mu, sigma, 10000)

# %%
sns.displot(x, color='gray')
ax.set_xlim(0, 100)
plt.axvline(mu, color='orange')
for v in [-3, -2, -1, 1, 2, 3]:
    plt.axvline(mu+v*sigma, color='olivedrab')
_ = plt.axvline(x_i, color='purple')

# %%
z = (x_i - mu)/sigma
z
# Out:
# 2.5

# %%
z = (x_i - np.mean(x))/np.std(x)
z
# Out:
# np.float64(2.5058740588062576)

# %%
x_i = 85
mu = 60
sigma = 10


x = np.random.normal(mu, sigma, 10000)


z = (x_i - mu) / sigma
print("Z-score using mu and sigma:", z)


z = (x_i - np.mean(x)) / np.std(x)
print("Z-score using sample mean/std:", z)


count = len(np.where(x > 85)[0])
print("Count greater than 85:", count)


percentage = 100 * count / 10000
print("Percentage greater than 85:", percentage)


p99 = np.percentile(x, 99)
print("99th percentile:", p99)


mu = 90
sigma = 2

print("New mu:", mu)
print("New sigma:", sigma)


y = np.random.normal(mu, sigma, 10000)


sns.displot(y, color='gray')


plt.axvline(mu, color='orange')


for v in [-3, -2, -1, 1, 2, 3]:
    plt.axvline(mu + v * sigma, color='olivedrab')


plt.axvline(x_i, color='purple')
# Out:
# Z-score using mu and sigma: 2.5
# Z-score using sample mean/std: 2.4867929436644003
# Count greater than 85: 65
# Percentage greater than 85: 0.65
# 99th percentile: 83.5903683391042
# New mu: 90
# New sigma: 2
